# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("../Data/processed/team_dominance_index.csv")
print("✅ Loaded processed dataset:", df.shape)
df.head()
# Out:
# ✅ Loaded processed dataset: (1065, 12)
#    year constructorId        name  races  wins  podiums  avg_finish  \
# 0  1950         adams       Adams      1     0        0   29.500000
# 1  1950    alfa-romeo  Alfa Romeo      6     6       11    6.954545
# 2  1950          alta        Alta      2     0        0   13.333333
# 3  1950        cooper      Cooper      1     0        0   15.000000
# 4  1950         deidt       Deidt      1     0        2   13.000000
#
#    total_points  win_rate  podium_rate  avg_points       TDI
# 0           0.0       0.0     0.000000    0.000000  0.003390
# 1          89.0       1.0     1.833333   14.833333  0.972938
# 2           0.0       0.0     0.000000    0.000000  0.007500
# 3           0.0       0.0     0.000000    0.000000  0.006667
# 4          10.0       0.0     2.000000   10.000000  0.575260

# %% [markdown]
# ### Normalize Metrics (Scaling 0–1)
# converts each metric into a 0–1 scale per year — meaning the best team in each category gets 1.0, and others are fractions of that.

# %%
metrics = ["win_rate", "podium_rate", "total_points"]

for year in df["year"].unique():
    mask = df["year"] == year
    for col in metrics:
        max_val = df.loc[mask, col].max()
        if max_val > 0:
            df.loc[mask, col] = df.loc[mask, col] / max_val

print("✅ Normalized metrics (0–1 scale)")
df.head()
# Out:
# ✅ Normalized metrics (0–1 scale)
#    year constructorId        name  races  wins  podiums  avg_finish  \
# 0  1950         adams       Adams      1     0        0   29.500000
# 1  1950    alfa-romeo  Alfa Romeo      6     6       11    6.954545
# 2  1950          alta        Alta      2     0        0   13.333333
# 3  1950        cooper      Cooper      1     0        0   15.000000
# 4  1950         deidt       Deidt      1     0        2   13.000000
#
#    total_points  win_rate  podium_rate  avg_points       TDI
# 0       0.00000       0.0     0.000000    0.000000  0.003390
# 1       1.00000       1.0     0.916667   14.833333  0.972938
# 2       0.00000       0.0     0.000000    0.000000  0.007500
# 3       0.00000       0.0     0.000000    0.000000  0.006667
# 4       0.11236       0.0     1.000000   10.000000  0.575260

# %% [markdown]
# ### Compute / Refine Team Dominance Index (TDI)
# Combine all normalized metrics into a single dominance score for each team-season.

# %%
# Recalculate or refine TDI if you want to change weights
w1, w2, w3 = 0.35, 0.25, 0.40  # (Win rate, Podium rate, Points share)

df["TDI"] = (
    w1 * df["win_rate"] +
    w2 * df["podium_rate"] +
    w3 * df["total_points"]
)

print("✅ TDI recalculated with updated weights")
df.head()
# Out:
# ✅ TDI recalculated with updated weights
#    year constructorId        name  races  wins  podiums  avg_finish  \
# 0  1950         adams       Adams      1     0        0   29.500000
# 1  1950    alfa-romeo  Alfa Romeo      6     6       11    6.954545
# 2  1950          alta        Alta      2     0        0   13.333333
# 3  1950        cooper      Cooper      1     0        0   15.000000
# 4  1950         deidt       Deidt      1     0        2   13.000000
#
#    total_points  win_rate  podium_rate  avg_points       TDI
# 0       0.00000       0.0     0.000000    0.000000  0.000000
# 1       1.00000       1.0     0.916667   14.833333  0.979167
# 2       0.00000       0.0     0.000000    0.000000  0.000000
# 3       0.00000       0.0     0.000000    0.000000  0.000000
# 4       0.11236       0.0     1.000000   10.000000  0.294944

# %%
df.to_csv("../Data/processed/team_year_summary.csv", index=False)
print("✅ Saved team_year_summary.csv")
# Out:
# ✅ Saved team_year_summary.csv
